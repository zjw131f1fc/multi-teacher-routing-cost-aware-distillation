# %%
from methods.rl_teacher_selection import (
    get_mock_data,
    compute_gradient,
    compute_validation_gradient,
)

# %%
data = get_mock_data(num_instructions=100, num_val_samples=50, device="cpu")

# %%
print(data.keys())
# Out:
# dict_keys(['instructions', 'student_model', 'teachers', 'val_loader'])
